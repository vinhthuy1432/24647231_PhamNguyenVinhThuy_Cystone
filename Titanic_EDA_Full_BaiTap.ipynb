# %% [markdown]
# # BÀI TẬP: EDA HOÀN CHỈNH — TITANIC
# ## Data Profiling → Descriptive Statistics → Define the Question
# **Nguồn:** kaggle.com/c/titanic (891 dòng)
#
# ```
# PHẦN A — DATA PROFILING       : dữ liệu sạch chưa, có gì
# PHẦN B — DESCRIPTIVE STATS    : từng biến trông như thế nào
# PHẦN C — DEFINE THE QUESTION  : đặt câu hỏi kinh doanh, trả lời bằng code, rút insight
# ```

# %% [markdown]
# ## Setup

# %%
# !pip install matplotlib seaborn
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\vinht\appdata\roaming\python\python39\site-packages (3.9.4)
# Requirement already satisfied: seaborn in c:\users\vinht\appdata\roaming\python\python39\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.1)
# Requirement already satisfied: six>=1.5 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from pandas>=1.2->seaborn) (2026.3.post1)
# WARNING: You are using pip version 21.1.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: You are using pip version 21.1.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\vinht\appdata\roaming\python\python39\site-packages (from scipy) (2.0.2)
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
from pathlib import Path
from scipy import stats

sns.set_style('whitegrid')

csv_path = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'

df = pd.read_csv(csv_path)
print('Loaded from:', csv_path)
df.head()
# Out:
# Loaded from: https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 11         1       1  female  58.0      0      0   26.5500        S   First
# 12         0       3    male  20.0      0      0    8.0500        S   Third
# 13         0       3    male  39.0      1      5   31.2750        S   Third
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 15         1       2  female  55.0      0      0   16.0000        S  Second
# 16         0       3    male   2.0      4      1   29.1250        Q   Third
# 17         1       2    male   NaN      0      0   13.0000        S  Second
# 18         0       3  female  31.0      1      0   18.0000        S   Third
# 19         1       3  female   NaN      0      0    7.2250        C   Third
# 20         0       2    male  35.0      0      0   26.0000        S  Second
# 21         1       2    male  34.0      0      0   13.0000        S  Second
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 23         1       1    male  28.0      0      0   35.5000        S   First
# 24         0       3  female   8.0      3      1   21.0750        S   Third
# 25         1       3  female  38.0      1      5   31.3875        S   Third
# 26         0       3    male   NaN      0      0    7.2250        C   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 28         1       3  female   NaN      0      0    7.8792        Q   Third
# 29         0       3    male   NaN      0      0    7.8958        S   Third
# 30         0       1    male  40.0      0      0   27.7208        C   First
# 31         1       1  female   NaN      1      0  146.5208        C   First
# 32         1       3  female   NaN      0      0    7.7500        Q   Third
# 33         0       2    male  66.0      0      0   10.5000        S  Second
# 34         0       1    male  28.0      1      0   82.1708        C   First
# 35         0       1    male  42.0      1      0   52.0000        S   First
# 36         1       3    male   NaN      0      0    7.2292        C   Third
# 37         0       3    male  21.0      0      0    8.0500        S   Third
# 38         0       3  female  18.0      2      0   18.0000        S   Third
# 39         1       3  female  14.0      1      0   11.2417        C   Third
# 40         0       3  female  40.0      1      0    9.4750        S   Third
# 41         0       2  female  27.0      1      0   21.0000        S  Second
# 42         0       3    male   NaN      0      0    7.8958        C   Third
# 43         1       2  female   3.0      1      2   41.5792        C  Second
# 44         1       3  female  19.0      0      0    7.8792        Q   Third
# 45         0       3    male   NaN      0      0    8.0500        S   Third
# 46         0       3    male   NaN      1      0   15.5000        Q   Third
# 47         1       3  female   NaN      0      0    7.7500        Q   Third
# 48         0       3    male   NaN      2      0   21.6792        C   Third
# 49         0       3  female  18.0      1      0   17.8000        S   Third
#
#       who  adult_male deck  embark_town alive  alone  family_size
# 0     man        True  NaN  Southampton    no  False            2
# 1   woman       False    C    Cherbourg   yes  False            2
# 2   woman       False  NaN  Southampton   yes   True            1
# 3   woman       False    C  Southampton   yes  False            2
# 4     man        True  NaN  Southampton    no   True            1
# 5     man        True  NaN   Queenstown    no   True            1
# 6     man        True    E  Southampton    no   True            1
# 7   child       False  NaN  Southampton    no  False            5
# 8   woman       False  NaN  Southampton   yes  False            3
# 9   child       False  NaN    Cherbourg   yes  False            2
# 10  child       False    G  Southampton   yes  False            3
# 11  woman       False    C  Southampton   yes   True            1
# 12    man        True  NaN  Southampton    no   True            1
# 13    man        True  NaN  Southampton    no  False            7
# 14  child       False  NaN  Southampton    no   True            1
# 15  woman       False  NaN  Southampton   yes   True            1
# 16  child       False  NaN   Queenstown    no  False            6
# 17    man        True  NaN  Southampton   yes   True            1
# 18  woman       False  NaN  Southampton    no  False            2
# 19  woman       False  NaN    Cherbourg   yes   True            1
# 20    man        True  NaN  Southampton    no   True            1
# 21    man        True    D  Southampton   yes   True            1
# 22  child       False  NaN   Queenstown   yes   True            1
# 23    man        True    A  Southampton   yes   True            1
# 24  child       False  NaN  Southampton    no  False            5
# 25  woman       False  NaN  Southampton   yes  False            7
# 26    man        True  NaN    Cherbourg    no   True            1
# 27    man        True    C  Southampton    no  False            6
# 28  woman       False  NaN   Queenstown   yes   True            1
# 29    man        True  NaN  Southampton    no   True            1
# 30    man        True  NaN    Cherbourg    no   True            1
# 31  woman       False    B    Cherbourg   yes  False            2
# 32  woman       False  NaN   Queenstown   yes   True            1
# 33    man        True  NaN  Southampton    no   True            1
# 34    man        True  NaN    Cherbourg    no  False            2
# 35    man        True  NaN  Southampton    no  False            2
# 36    man        True  NaN    Cherbourg   yes   True            1
# 37    man        True  NaN  Southampton    no   True            1
# 38  woman       False  NaN  Southampton    no  False            3
# 39  child       False  NaN    Cherbourg   yes  False            2
# 40  woman       False  NaN  Southampton    no  False            2
# 41  woman       False  NaN  Southampton    no  False            2
# 42    man        True  NaN    Cherbourg    no   True            1
# 43  child       False  NaN    Cherbourg   yes  False            4
# 44  woman       False  NaN   Queenstown   yes   True            1
# 45    man        True  NaN  Southampton    no   True            1
# 46    man        True  NaN   Queenstown    no  False            2
# 47  woman       False  NaN   Queenstown   yes   True            1
# 48    man        True  NaN    Cherbourg    no  False            3
# 49  woman       False  NaN  Southampton    no  False            2

# %% [markdown]
# ---
# # PHẦN A — DATA PROFILING
# ## A.1. Data size, column names, data types

# %%
# TODO
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# ## A.2. Missing values & Duplicate data

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(107)

# %% [markdown]
# ## A.3. Invalid values

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## A.4. Create a new column
# Tạo cột `family_size` = sibsp + parch + 1.

# %%
df['family_size'] = df['sibsp'] + df['parch'] + 1
df[['sibsp', 'parch', 'family_size']].head(10)
# Out:
#    sibsp  parch  family_size
# 0      1      0            2
# 1      1      0            2
# 2      0      0            1
# 3      1      0            2
# 4      0      0            1
# 5      0      0            1
# 6      0      0            1
# 7      3      1            5
# 8      0      2            3
# 9      1      0            2

# %% [markdown]
# ---
# # PHẦN B — DESCRIPTIVE STATISTICS
# ## Group 1 — Central Tendency

# %%
df[['age', 'fare']].mean()
# Out:
# age     29.699118
# fare    32.204208
# dtype: float64

# %%
df[['age', 'fare']].median()
# Out:
# age     28.0000
# fare    14.4542
# dtype: float64

# %%
df[['age', 'fare', 'pclass', 'sex']].mode()
# Out:
#     age  fare  pclass   sex
# 0  24.0  8.05       3  male

# %% [markdown]
# ## Group 2 — Dispersion

# %%
df[['age', 'fare']].std()
# Out:
# age     14.526497
# fare    49.693429
# dtype: float64

# %%
df[['age', 'fare']].var()
# Out:
# age      211.019125
# fare    2469.436846
# dtype: float64

# %%
R_age = df['age'].max() - df['age'].min()
R_fare = df['fare'].max() - df['fare'].min()
print('Range age:', R_age)
print('Range fare:', R_fare)
# Out:
# Range age: 79.58
# Range fare: 512.3292

# %% [markdown]
# ## Group 3 — Location and Shape

# %%
print('độ lệch :\n',df[['age', 'fare']].skew())
print('độ nhọn :\n',df[['age', 'fare']].kurt())
# Out:
# độ lệch :
#  age     0.389108
# fare    4.787317
# dtype: float64
# độ nhọn :
#  age      0.178274
# fare    33.398141
# dtype: float64

# %% [markdown]
# ---
# # PHẦN C — DEFINE THE QUESTION
#
# ## Câu hỏi 1: Hạng vé nào có tỷ lệ sống sót cao nhất, chênh lệch bao nhiêu so với hạng thấp nhất?

# %%
sv = df.groupby('pclass')['survived'].mean() * 100
print('Tỷ lệ sống sót theo hạng vé:\n', sv)
cl = sv.max()- sv.min()
print('Chênh lệch tỷ lệ sống sót giữa hạng vé cao nhất và thấp nhất:', cl)
# Out:
# Tỷ lệ sống sót theo hạng vé:
#  pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: survived, dtype: float64
# Chênh lệch tỷ lệ sống sót giữa hạng vé cao nhất và thấp nhất: 38.726710417138115

# %% [markdown]
# ## Câu hỏi 2: Giới tính hay hạng vé ảnh hưởng đến sống sót mạnh hơn?

# %%
df.groupby(['sex', 'pclass'])['survived'].mean() * 100
# Out:
# sex     pclass
# female  1         96.808511
#         2         92.105263
#         3         50.000000
# male    1         36.885246
#         2         15.740741
#         3         13.544669
# Name: survived, dtype: float64

# %% [markdown]
# Phụ nữ có tỷ lệ sống cao hơn nam giới rất nhiều ở mọi hạng vé => giới tính ảnh hưởng mạnh mẽ nhất, tuy nhiên hạng vé cũng quan trọng vì nam giới có hạng vé 1 sống sót cao hơn nam giới có hạng vé 3

# %% [markdown]
# ## Câu hỏi 3: Vé đắt hơn có thực sự sống sót cao hơn không?

# %%
df.groupby('survived')['fare'].mean()
# Out:
# survived
# 0    22.117887
# 1    48.395408
# Name: fare, dtype: float64

# %% [markdown]
# Có, những khách hàng sống sót có giá vé trung bình cao hơn gấp đôi so với những khách không sống sót

# %% [markdown]
# ## Câu hỏi 4: Gia đình đông người có ảnh hưởng đến khả năng sống sót không?

# %%
df.groupby('family_size')['survived'].mean() * 100
# Out:
# family_size
# 1     30.353818
# 2     55.279503
# 3     57.843137
# 4     72.413793
# 5     20.000000
# 6     13.636364
# 7     33.333333
# 8      0.000000
# 11     0.000000
# Name: survived, dtype: float64

# %% [markdown]
# Có, hàng khách đi cùng gia đình từ 2 đến 4 người có tỷ lệ sống sót cao nhất (55-73%), những khách hàng đi một mình hoặc cùng gia đình từ 5 người trở lên có tỷ lệ sống sót thấp hơn

# %% [markdown]
# ## Câu hỏi 5: Cảng lên tàu (embark_town) nào có tỷ lệ sống sót cao nhất?

# %%
df.groupby('embark_town')['survived'].mean() * 100
# Out:
# embark_town
# Cherbourg      55.357143
# Queenstown     38.961039
# Southampton    33.695652
# Name: survived, dtype: float64

# %% [markdown]
# Cảng cherbourg có tỷ lệ sống sót cao nhất

# %% [markdown]
# ## Câu hỏi 6 (Tổng hợp) — Viết insight tổng hợp
# Dựa trên Phần A, B, C, viết 4-5 câu insight tổng thể về dữ liệu Titanic.

# %% [markdown]
# *(Viết insight của bạn vào đây...)*

# %% [markdown]
# Trong thảm kịch giới tính nữ có tỷ lệ sống sót vượt trội so với nam giới ỏ bất kỳ hạng vé nào
# Khách hàng có vé hạng một hoặc trả giá vé cao có tỷ lệ sống sót cao rất nhiều lần
# Việc có người thân đi cùng cũng mang lại lợi thế sinh tồn, tuy nhiên chỉ đúng với các gia đình từ 2 đến 4 người. Những người đi 1 mình hoặc gia đình qua đông đều gặp bất lợi trong việc sơ tán
